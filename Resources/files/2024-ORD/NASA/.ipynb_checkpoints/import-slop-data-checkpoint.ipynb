# %%
import thermomatch as match
# Out:
# [2024-08-27 18:17:55.880] [jsonio17] [info] Home directory is /home/dmiron

# %%
# Set path to `schemas` and `lua` not from the configuration file
match.ThermoImpexGenerator.setResourcesDirectory("../../../../Resources")

# Connect to Arango database
generator = match.ThermoImpexGenerator("http://localhost:8529", "root", "", "test_import_slop17", True, match.ThermoImpexGenerator.File, True)

# %%
# Import References (the collection name and VertexDataSource schema would be obtained from the script by default)
keys = generator.importFileToDatabase("FormatStructDataFile", "scripts/references.FormatStructDataFile.json", "data/refs.slop16.json", "")  #- bug

# %%
# Import Elements (the collection name and VertexElements schema would be obtained from the script by default)
# Connect to Arango database
generator = match.ThermoImpexGenerator("http://localhost:8529", "root", "", "test_import_slop17", True, match.ThermoImpexGenerator.File, True)
keys = generator.importFileToDatabase("FormatTableFile", "scripts/elements.FormatTableFile.json", "data/elements.csv", "")

# %%
# List of implemented thermodynamic formats
# print( generator.allFormats() )

# Execute import from PSI table format data
description = [
    match.ImpexRowDescription("Minerals", "VertexSubstance", "recrods", "FormatTableFile", "scripts/minerals.FormatTableFile.json"), # subtance records for minerals 
    match.ImpexRowDescription("MineralsOnePhaseTransition", "VertexSubstance", "recrods", "FormatTableFile", "scripts/onephaseminerals.FormatTableFile.json"), # substance records for minerals with one phase transition
    match.ImpexRowDescription("MineralsTwoPhaseTransition", "VertexSubstance", "recrods", "FormatTableFile", "scripts/twophaseminerals.FormatTableFile.json"), # substance records for minerals with two phase transitions
    match.ImpexRowDescription("MineralsThreePhaseTransition", "VertexSubstance", "recrods", "FormatTableFile", "scripts/threephaseminerals.FormatTableFile.json"), # substance records for minerals with three phase transitions
    match.ImpexRowDescription("Gases", "VertexSubstance", "recrods", "FormatTableFile", "scripts/gases.FormatTableFile.json"), # substance records for gases
    match.ImpexRowDescription("AqueousSpecies", "VertexSubstance", "recrods", "FormatTableFile", "scripts/aqueous_species.FormatTableFile.json"), # substance records for aqueous species
    match.ImpexRowDescription("ThermoDataSet", "VertexThermoDataSet", "records_and_links", "FormatTableFile", "scripts/thermodataset.FormatTableFile.json")  # ThermoDataSet record and link to elements, substances, rdc
]

# %%
#print( description )
generator.runImport("SlopImport", description, "data/slop16.dat", "");
# Out:
# [2024-08-27 18:17:56.151] [thermomatch] [info]  0% Preparing files ...
# [2024-08-27 18:17:56.209] [thermomatch] [info]  10% Importing data ...
# [2024-08-27 18:17:56.209] [thermomatch] [info]  10% Importing Minerals VertexSubstance ...
# [2024-08-27 18:17:57.221] [thermomatch] [info]  18% Importing MineralsOnePhaseTransition VertexSubstance ...
# [2024-08-27 18:17:57.341] [thermomatch] [info]  26% Importing MineralsTwoPhaseTransition VertexSubstance ...
# [2024-08-27 18:17:57.427] [thermomatch] [info]  34% Importing MineralsThreePhaseTransition VertexSubstance ...
# [2024-08-27 18:17:57.440] [thermomatch] [info]  42% Importing Gases VertexSubstance ...
# [2024-08-27 18:17:57.508] [thermomatch] [info]  50% Importing AqueousSpecies VertexSubstance ...
# [2024-08-27 18:18:01.920] [thermomatch] [info]  58% Importing ThermoDataSet VertexThermoDataSet ...
# [2024-08-27 18:18:01.923] [thermomatch] [info]  80% Load database to compare ...
# ...

# %%
# To Do
# make pure phases
