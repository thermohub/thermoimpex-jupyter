# %%
import thermomatch as match
match.ThermoImpexGenerator.create_local_database_if_not_existent = True

# %%
# Set path to `schemas` and `lua` not from the configuration file
match.ThermoImpexGenerator.setResourcesDirectory("../../../../Resources")

# Connect to Arango database
generator = match.ThermoImpexGenerator("http://localhost:8529", "root", "", "test_import_nasa_53", True, match.ThermoImpexGenerator.File, True)
# Out:
# [jsonarango] [info] You are connected to: arango 3.9.12

# %%
# Import References (the collection name and VertexDataSource schema would be obtained from the script by default)
# keys = generator.importFileToDatabase("FormatTableFile", "scripts/thermo.FormatTableFile.json", "data/thermo.inp", "")

# %%
# Execute import from PSI table format data
description = [
    match.ImpexRowDescription("elements", "VertexElement", "records", "FormatTableFile", "scripts/elements.FormatTableFile.json" ), # elements records NEA based
    match.ImpexRowDescription("thermo", "VertexSubstance", "records", "FormatTableFile", "scripts/thermo.FormatTableFile.json" ), # subtances records
    match.ImpexRowDescription("ThermoDataSet", "VertexThermoDataSet", "records_and_links", "FormatTableFile", "scripts/thermodataset.FormatTableFile.json") # ThermoDataSet record and link to elements, substances, rdc
]

# %%
generator.runImport("TableImport", description, "data/elements.nasa.inp", "");
# Out:
# [2024-09-06 16:06:49.514] [thermomatch] [info]  0% Preparing files ...
# [2024-09-06 16:06:49.515] [thermomatch] [info]  10% Importing data ...
# [2024-09-06 16:06:49.515] [thermomatch] [info]  10% Importing elements VertexElement ...
# [jsonio17] [info] VertexElement loading collection: 29, loading query: 955
# [2024-09-06 16:06:49.593] [thermomatch] [info]  30% Importing thermo VertexSubstance ...
# [jsonio17] [info] VertexSubstance loading collection: 21, loading query: 1063
# [2024-09-06 16:06:55.758] [thermomatch] [info]  50% Importing ThermoDataSet VertexThermoDataSet ...
# [jsonio17] [info] VertexThermoDataSet loading collection: 20, loading query: 1174
# [2024-09-06 16:06:55.760] [thermomatch] [info]  80% Load database to compare ...
# [2024-09-06 16:06:55.760] [thermomatch] [info]  90% Generate Edges ...
# [2024-09-06 16:06:55.760] [thermomatch] [info] Generate ThermoDataSet links
# [2024-09-06 16:06:56.500] [thermomatch] [info]  100% Ready to test
