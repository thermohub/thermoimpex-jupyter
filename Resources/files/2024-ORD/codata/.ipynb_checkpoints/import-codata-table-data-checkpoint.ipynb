# %%
import thermomatch as match
match.ThermoImpexGenerator.create_local_database_if_not_existent = True

# %%
# Set path to `schemas` and `lua` not from the configuration file
match.ThermoImpexGenerator.setResourcesDirectory("../../../../Resources")

# Connect to Arango database
generator = match.ThermoImpexGenerator("http://localhost:8529", "root", "", "test_import_codata_3", True, match.ThermoImpexGenerator.File, True)
# Out:
# [jsonarango] [info] You are connected to: arango 3.9.12

# %%
# List of implemented thermodynamic formats
# print( generator.allFormats() )

# Execute import from PSI table format data
description = [
    #match.ImpexRowDescription("icomp", "VertexElement", "records", "FormatTableFile", "scripts/elements.FormatTableFile.json"), # element records
    match.ImpexRowDescription("refs", "VertexDataSource", "records", "FormatStructDataFile", "scripts/references.FormatStructDataFile.json"), # reference records
    match.ImpexRowDescription("substances", "VertexSubstance", "records", "FormatTableFile", "scripts/master_substances.FormatTableFile.json"), # substance records for master aqeuous species
    #links to references
    match.ImpexRowDescription("dcomp-aqueous", "VertexTemporary", "records_and_links", "FormatTableFile", "scripts/master_substances_references.FormatTableFile.json"), # links to master substances from references
    # references
    # match.ImpexRowDescription("SIT", "VertexTemporary", "records_and_links", "FormatTableFile", "scripts/int_Na_references.FormatTableFile.json"), # not working yet
    match.ImpexRowDescription("ThermoDataSet", "VertexThermoDataSet", "records_and_links", "FormatTableFile", "scripts/thermodataset.FormatTableFile.json") # ThermoDataSet record and link to elements, substances, rdc
]

# %%
generator.runImport("TableImport", description, "data/refs.codata.csv", "");
#generator.runImport("TableImport", description, "data/dcomp-aqueous.Pu.csv", "rdc_PSITDB2020");
# Out:
# [2024-09-08 19:13:09.960] [thermomatch] [info]  0% Preparing files ...
# [2024-09-08 19:13:09.960] [thermomatch] [info]  10% Importing data ...
# [2024-09-08 19:13:09.960] [thermomatch] [info]  10% Importing refs VertexDataSource ...
# [jsonio17] [info] VertexDataSource loading collection: 815, loading query: 1158
# [2024-09-08 19:13:09.967] [thermomatch] [info]  25% Importing substances VertexSubstance ...
# [jsonio17] [info] VertexSubstance loading collection: 17, loading query: 1528
# [2024-09-08 19:13:10.370] [thermomatch] [info]  40% Importing dcomp-aqueous VertexTemporary ...
# [2024-09-08 19:13:10.370] [thermomatch] [info]  55% Importing ThermoDataSet VertexThermoDataSet ...
# [jsonio17] [info] VertexThermoDataSet loading collection: 18, loading query: 1222
# [2024-09-08 19:13:10.372] [thermomatch] [info]  80% Load database to compare ...
# [2024-09-08 19:13:10.372] [thermomatch] [info]  90% Generate Edges ...
# [2024-09-08 19:13:10.372] [thermomatch] [info] Generate DataSource links
# [jsonio17] [info] VertexTemporary loading collection: 854, loading query: 1431
# [jsonio17] [info] VertexDataSource loading collection: 39, loading query: 1511
# [2024-09-08 19:13:10.378] [thermomatch] [info] Generate ThermoDataSet links
# [2024-09-08 19:13:10.453] [thermomatch] [info]  100% Ready to test

# %%
# to do - script to loop through elements

# %%
# update data of elements from CODATA, NEA and SUCPRT
fields_list = [ "_id", "properties.symbol" ]
generator.updateFileToDatabase("FormatTableFile", "scripts/elements_update.FormatTableFile.json",
                    "../elements/data/elements.csv", "", "", fields_list )
