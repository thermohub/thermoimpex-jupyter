# %%
import thermomatch as match
match.ThermoImpexGenerator.create_local_database_if_not_existent = True

# %%
# Set path to `schemas` and `lua` not from the configuration file
match.ThermoImpexGenerator.setResourcesDirectory("../../../../Resources")

# Connect to Arango database
generator = match.ThermoImpexGenerator("http://localhost:8529", "root", "", "ORD_mines23", True, match.ThermoImpexGenerator.File, False)
# Out:
# [jsonarango] [info] You are connected to: arango 3.9.12

# %%
# List of implemented thermodynamic formats
#print( generator.allFormats() )

# Execute import from PSI table format data
description = [
    match.ImpexRowDescription("refs", "VertexDataSource", "records_and_links", "FormatStructDataFile", "scripts/references.FormatStructDataFile.json"), # Datasource records 
    match.ImpexRowDescription("elements", "VertexElement", "records", "FormatStructDataFile", "scripts/Element.mines23.FormatStructDataFile.json"), # elements records
    match.ImpexRowDescription("aqueous", "VertexSubstance", "records", "FormatStructDataFile", "scripts/Substance.mines23.FormatStructDataFile.json"), # aqueous substances records
    match.ImpexRowDescription("solids", "VertexSubstance", "records", "FormatStructDataFile", "scripts/Substance.mines23.FormatStructDataFile.json"), # solid substances records
    match.ImpexRowDescription("fluids", "VertexSubstance", "records", "FormatStructDataFile", "scripts/Substance.mines23.FormatStructDataFile.json"), # fluid substances records
    match.ImpexRowDescription("reactions", "VertexSubstance", "records", "FormatStructDataFile", "scripts/ReactionSubstance.mines23.FormatStructDataFile.json"), # reaction dependent substances records
    match.ImpexRowDescription("reactions", "VertexReaction", "group", "FormatStructDataFile", "scripts/Reaction.mines23.FormatStructDataFile.json"), # reaction records
    match.ImpexRowDescription("reactions", "EdgeTakes", "group", "FormatStructDataFile", "scripts/ReactionEdge.mines23.FormatStructDataFile.json"), # links between reactants and reaction records
    match.ImpexRowDescription("phasespure", "VertexPhase", "records_and_links", "FormatStructDataFile", "scripts/Phase.mines23.FormatStructDataFile.json"), # phase records
    match.ImpexRowDescription("ThermoDataSet", "VertexThermoDataSet", "records_and_links", "FormatTableFile", "scripts/thermodataset.FormatTableFile.json") # thermodataset record
]

# %%
#print( description )
generator.runImport("ReacDCImport", description, "data/mines23.refs.json", "mines23");
# Out:
# [2024-09-08 16:47:19.778] [thermomatch] [info]  0% Preparing files ...
# [2024-09-08 16:47:19.778] [thermomatch] [info]  File name for block data/mines23.refs.json
# [2024-09-08 16:47:19.778] [thermomatch] [info]  File name for block data/mines23.elements.json
# [2024-09-08 16:47:19.778] [thermomatch] [info]  File name for block data/mines23.aqueous.json
# [2024-09-08 16:47:19.778] [thermomatch] [info]  File name for block data/mines23.solids.json
# [2024-09-08 16:47:19.778] [thermomatch] [info]  File name for block data/mines23.fluids.json
# [2024-09-08 16:47:19.778] [thermomatch] [info]  File name for block data/mines23.reactions.json
# [2024-09-08 16:47:19.778] [thermomatch] [info]  File name for block data/mines23.reactions.json
# [2024-09-08 16:47:19.778] [thermomatch] [info]  File name for block data/mines23.reactions.json
# [2024-09-08 16:47:19.778] [thermomatch] [info]  File name for block data/mines23.phasespure.json
# [2024-09-08 16:47:19.778] [thermomatch] [info]  File name for block data/mines23.ThermoDataSet.json
# [2024-09-08 16:47:19.778] [thermomatch] [info]  10% Importing data ...
# [2024-09-08 16:47:19.778] [thermomatch] [info]  10% Importing refs VertexDataSource ...
# [jsonio17] [info] VertexDataSource loading collection: 4621, loading query: 1584
# [2024-09-08 16:47:19.971] [thermomatch] [info]  16% Importing elements VertexElement ...
# [jsonio17] [info] VertexElement loading collection: 4893, loading query: 2724
# [2024-09-08 16:47:20.038] [thermomatch] [info]  22% Importing aqueous VertexSubstance ...
# [jsonio17] [info] VertexSubstance loading collection: 4597, loading query: 1394
# [2024-09-08 16:47:21.890] [thermomatch] [info]  28% Importing solids VertexSubstance ...
# [2024-09-08 16:47:23.603] [thermomatch] [info]  34% Importing fluids VertexSubstance ...
# [2024-09-08 16:47:23.665] [thermomatch] [info]  40% Importing reactions VertexSubstance ...
# [2024-09-08 16:47:23.934] [thermomatch] [info]  46% Importing reactions VertexReaction ...
# [jsonio17] [info] VertexSubstance loading collection: 43, loading query: 156768
# [2024-09-08 16:47:26.037] [thermomatch] [info]  58% Importing phasespure VertexPhase ...
# [jsonio17] [info] VertexPhase loading collection: 8385, loading query: 1533
# [2024-09-08 16:47:26.742] [thermomatch] [info]  64% Importing ThermoDataSet VertexThermoDataSet ...
# [jsonio17] [info] VertexThermoDataSet loading collection: 7826, loading query: 1499
# [2024-09-08 16:47:26.754] [thermomatch] [info]  80% Load database to compare ...
# [2024-09-08 16:47:26.754] [thermomatch] [info]  90% Generate Edges ...
# [2024-09-08 16:47:26.754] [thermomatch] [info] Generate DataSource links
# [jsonio17] [info] VertexReaction loading collection: 31, loading query: 11398
# [jsonio17] [info] VertexSubstance loading collection: 29, loading query: 157197
# [jsonio17] [info] VertexDataSource loading collection: 46, loading query: 13719
# [2024-09-08 16:47:28.463] [thermomatch] [info] Generate Pure Phase links
# [jsonio17] [info] VertexPhase loading collection: 22, loading query: 49838
# [jsonio17] [info] VertexSubstance loading collection: 94, loading query: 747
# [2024-09-08 16:47:29.047] [thermomatch] [warning] No substance Ferrousoxide found to link to phase Ferrous-oxide check that the symbols agree.
# [2024-09-08 16:47:29.135] [thermomatch] [warning] No substance Tungstendioxide found to link to phase Tungsten-dioxide check that the symbols agree.
# [2024-09-08 16:47:29.144] [thermomatch] [warning] No substance Zinctitaniumsp found to link to phase Zinc-titanium-sp check that the symbols agree.
# [2024-09-08 16:47:29.188] [thermomatch] [warning] No substance Tschermakstalc found to link to phase Tschermaks talc check that the symbols agree.
# [2024-09-08 16:47:29.192] [thermomatch] [warning] No substance Ca-tschermakpyr found to link to phase Ca-tschermak Pyr check that the symbols agree.
# [2024-09-08 16:47:29.203] [thermomatch] [warning] No substance Mg-tschermakpyr found to link to phase Mg-tschermak Pyr check that the symbols agree.
# [2024-09-08 16:47:29.215] [thermomatch] [warning] No substance Hydrouscordieri found to link to phase Hydrous Cordieri check that the symbols agree.
# [2024-09-08 16:47:29.274] [thermomatch] [warning] No substance Mgsulfate_x found to link to phase Mg-sulfate check that the symbols agree.
# [2024-09-08 16:47:29.389] [thermomatch] [info] Generate ThermoDataSet links
# [2024-09-08 16:47:29.823] [thermomatch] [info]  100% Ready to test
