# %%
import thermomatch as match
match.ThermoImpexGenerator.create_local_database_if_not_existent = True

# %%
# Set path to `schemas` and `lua` not from the configuration file
match.ThermoImpexGenerator.setResourcesDirectory("../../../../Resources")

# Connect to Arango database
generator = match.ThermoImpexGenerator("http://localhost:8529", "root", "", "test_import_cemdata18_21", True, match.ThermoImpexGenerator.File, False)
# Out:
# [jsonarango] [info] You are connected to: arango 3.9.12

# %%
generator.sourcedtbs = (["{\"20\" : \"CEMDATA18\"}", "{\"15\" : \"PSI_NAGRA\"}"])

# %%
# List of implemented thermodynamic formats
#print( generator.allFormats() )

# Execute import from PSI table format data
description = [
    match.ImpexRowDescription("refs", "VertexDataSource", "records_and_links", "FormatStructDataFile", "scripts/references.FormatStructDataFile.json"), # Datasource records 
    match.ImpexRowDescription("elements-psina12_07", "VertexElement", "records", "FormatStructDataFile", "scripts/Element.cemdata-psina.FormatStructDataFile.json"), # elements records
    match.ImpexRowDescription("aqueous-psina12_07", "VertexSubstance", "records", "FormatStructDataFile", "scripts/Substance.cemdata-psina.FormatStructDataFile.json"), # aqueous substances records
    match.ImpexRowDescription("solids-psina12_07", "VertexSubstance", "records", "FormatStructDataFile", "scripts/Substance.cemdata-psina.FormatStructDataFile.json"), # solid substances records
    match.ImpexRowDescription("aqueous", "VertexSubstance", "records", "FormatStructDataFile", "scripts/Substance.cemdata.FormatStructDataFile.json"), # aqueous substances records
    match.ImpexRowDescription("solids", "VertexSubstance", "records", "FormatStructDataFile", "scripts/Substance.cemdata.FormatStructDataFile.json"), # solid substances records
    match.ImpexRowDescription("gases-psina12_07", "VertexSubstance", "records", "FormatStructDataFile", "scripts/Substance.cemdata-psina.FormatStructDataFile.json"), # fluid substances records
    match.ImpexRowDescription("reactions-psina12_07", "VertexSubstance", "records", "FormatStructDataFile", "scripts/ReactionSubstance.cemdata-psina.FormatStructDataFile.json"), # reaction dependent substances records
    match.ImpexRowDescription("reactions", "VertexSubstance", "records", "FormatStructDataFile", "scripts/ReactionSubstance.cemdata.FormatStructDataFile.json"), # reaction dependent substances records
    match.ImpexRowDescription("reactions-psina12_07", "VertexReaction", "group", "FormatStructDataFile", "scripts/Reaction.cemdata-psina.FormatStructDataFile.json"), # reaction records
    match.ImpexRowDescription("reactions-psina12_07", "EdgeTakes", "group", "FormatStructDataFile", "scripts/ReactionEdge.FormatStructDataFile.json"), # links between reactants and reaction records
    match.ImpexRowDescription("reactions", "VertexReaction", "group", "FormatStructDataFile", "scripts/Reaction.cemdata.FormatStructDataFile.json"), # reaction records
    match.ImpexRowDescription("reactions", "EdgeTakes", "group", "FormatStructDataFile", "scripts/ReactionEdge.FormatStructDataFile.json"), # links between reactants and reaction records
    match.ImpexRowDescription("phases-psina12_07", "VertexPhase", "records_and_links", "FormatStructDataFile", "scripts/Phase.cemdata-psina.FormatStructDataFile.json"), # phase records
    match.ImpexRowDescription("phases", "VertexPhase", "records_and_links", "FormatStructDataFile", "scripts/Phase.cemdata.FormatStructDataFile.json"), # phase records
    match.ImpexRowDescription("ThermoDataSet", "VertexThermoDataSet", "records_and_links", "FormatTableFile", "scripts/thermodataset.FormatTableFile.json") # thermodataset record
]

# %%
#print( description )
generator.runImport("ReacDCImport", description, "data/cemdata18.refs.json", "Cemdata18");
# Out:
# [2024-09-06 15:20:19.382] [thermomatch] [info]  0% Preparing files ...
# [2024-09-06 15:20:19.382] [thermomatch] [info]  File name for block data/cemdata18.refs.json
# [2024-09-06 15:20:19.382] [thermomatch] [info]  File name for block data/cemdata18.elements-psina12_07.json
# [2024-09-06 15:20:19.382] [thermomatch] [info]  File name for block data/cemdata18.aqueous-psina12_07.json
# [2024-09-06 15:20:19.382] [thermomatch] [info]  File name for block data/cemdata18.solids-psina12_07.json
# [2024-09-06 15:20:19.382] [thermomatch] [info]  File name for block data/cemdata18.aqueous.json
# [2024-09-06 15:20:19.382] [thermomatch] [info]  File name for block data/cemdata18.solids.json
# [2024-09-06 15:20:19.382] [thermomatch] [info]  File name for block data/cemdata18.gases-psina12_07.json
# [2024-09-06 15:20:19.382] [thermomatch] [info]  File name for block data/cemdata18.reactions-psina12_07.json
# ...

# %%
# fix other sourcetdb - add in impex vector<string> surcetdbs - then add them in thermodataset...
